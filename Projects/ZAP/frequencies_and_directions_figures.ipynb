# %%
drive_path = 'd:/'

import numpy as np
import pandas as pd
import os
import sys


import matplotlib.pyplot as plt
# %matplotlib inline

from allensdk.core.brain_observatory_cache import BrainObservatoryCache

manifest_path = os.path.join(drive_path,'BrainObservatory/manifest.json')
boc = BrainObservatoryCache(manifest_file=manifest_path)

# %%
V1data=boc.get_ophys_experiments(targeted_structures=['VISp'])
Valdata=boc.get_ophys_experiments(targeted_structures=['VISal'])
Vlmdata=boc.get_ophys_experiments(targeted_structures=['VISl'])
Vpmdata=boc.get_ophys_experiments(targeted_structures=['VISpm'])

#session_ids=V1exps.id.values
V1expt_list=pd.DataFrame(V1data).experiment_container_id.unique()
Valexpt_list=pd.DataFrame(Valdata).experiment_container_id.unique()
Vlmexpt_list=pd.DataFrame(Vlmdata).experiment_container_id.unique()
Vpmexpt_list=pd.DataFrame(Vpmdata).experiment_container_id.unique()
# expt_container_id = expt_list[:]
#boc.get_experiment_containers(ids=[expt_list[0]])
V1cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=V1expt_list))
Valcell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=Valexpt_list))
Vlmcell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=Vlmexpt_list))
Vpmcell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=Vpmexpt_list))

V1cell_specimens_df=V1cell_specimens_df[np.isfinite(V1cell_specimens_df['pref_tf_dg'])]
Valcell_specimens_df=Valcell_specimens_df[np.isfinite(Valcell_specimens_df['pref_tf_dg'])]
Vlmcell_specimens_df=Vlmcell_specimens_df[np.isnan(Vlmcell_specimens_df.pref_sf_sg)==False]
Vpmcell_specimens_df=Vpmcell_specimens_df[np.isfinite(Vpmcell_specimens_df['pref_tf_dg'])]

V1cell_specimens_df=V1cell_specimens_df[np.isfinite(V1cell_specimens_df['pref_sf_sg'])]
Valcell_specimens_df=Valcell_specimens_df[np.isfinite(Valcell_specimens_df['pref_sf_sg'])]
Vlmcell_specimens_df=Vlmcell_specimens_df[np.isnan(Vlmcell_specimens_df.pref_tf_dg)==False]
Vpmcell_specimens_df=Vpmcell_specimens_df[np.isfinite(Vpmcell_specimens_df['pref_sf_sg'])]

# %%
Rbp4data=boc.get_ophys_experiments(cre_lines=['Rbp4-Cre'])
Rorbdata=boc.get_ophys_experiments(cre_lines=['Rorb-IRES2-Cre'])
Scnn1data=boc.get_ophys_experiments(cre_lines=['Scnn1a-Tg3-Cre'])
Cux2data=boc.get_ophys_experiments(cre_lines=['Cux2-CreERT2'])

Rbp4expt_list=pd.DataFrame(Rbp4data).experiment_container_id.unique()
Rorbexpt_list=pd.DataFrame(Rorbdata).experiment_container_id.unique()
Scnn1expt_list=pd.DataFrame(Scnn1data).experiment_container_id.unique()
Cux2expt_list=pd.DataFrame(Cux2data).experiment_container_id.unique()
# expt_container_id = expt_list[:]
#boc.get_experiment_containers(ids=[expt_list[0]])
Rbp4cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=Rbp4expt_list))
Rorbcell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=Rorbexpt_list))
Scnn1cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=Scnn1expt_list))
Cux2cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=Cux2expt_list))

Rbp4cell_specimens_df=Rbp4cell_specimens_df[np.isfinite(Rbp4cell_specimens_df['pref_tf_dg'])]
Rorbcell_specimens_df=Rorbcell_specimens_df[np.isfinite(Rorbcell_specimens_df['pref_tf_dg'])]
Scnn1cell_specimens_df=Scnn1cell_specimens_df[np.isnan(Scnn1cell_specimens_df.pref_tf_dg)==False]
Cux2cell_specimens_df=Cux2cell_specimens_df[np.isfinite(Cux2cell_specimens_df['pref_tf_dg'])]

Rbp4cell_specimens_df=Rbp4cell_specimens_df[np.isfinite(Rbp4cell_specimens_df['pref_sf_sg'])]
Rorbcell_specimens_df=Rorbcell_specimens_df[np.isfinite(Rorbcell_specimens_df['pref_sf_sg'])]
Scnn1cell_specimens_df=Scnn1cell_specimens_df[np.isnan(Scnn1cell_specimens_df.pref_sf_sg)==False]
Cux2cell_specimens_df=Cux2cell_specimens_df[np.isfinite(Cux2cell_specimens_df['pref_sf_sg'])]

# %%
PMRbp4data=boc.get_ophys_experiments(cre_lines=['Rbp4-Cre'],targeted_structures=['VISpm'])
PMRorbdata=boc.get_ophys_experiments(cre_lines=['Rorb-IRES2-Cre'],targeted_structures=['VISpm'])
#PMScnn1data=boc.get_ophys_experiments(cre_lines=['Scnn1a-Tg3-Cre'],targeted_structures=['VISpm'])
PMCux2data=boc.get_ophys_experiments(cre_lines=['Cux2-CreERT2'],targeted_structures=['VISpm'])

PMRbp4expt_list=pd.DataFrame(PMRbp4data).experiment_container_id.unique()
PMRorbexpt_list=pd.DataFrame(PMRorbdata).experiment_container_id.unique()
#PMScnn1expt_list=pd.DataFrame(PMScnn1data).experiment_container_id.unique()
PMCux2expt_list=pd.DataFrame(PMCux2data).experiment_container_id.unique()
# expt_container_id = expt_list[:]
#boc.get_experiment_containers(ids=[expt_list[0]])
PMRbp4cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=PMRbp4expt_list))
PMRorbcell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=PMRorbexpt_list))
#PMScnn1cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=PMScnn1expt_list))
PMCux2cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=PMCux2expt_list))

PMRbp4cell_specimens_df=PMRbp4cell_specimens_df[np.isfinite(PMRbp4cell_specimens_df['pref_tf_dg'])]
PMRorbcell_specimens_df=PMRorbcell_specimens_df[np.isfinite(PMRorbcell_specimens_df['pref_tf_dg'])]
#PMScnn1cell_specimens_df=PMScnn1cell_specimens_df[np.isnan(PMScnn1cell_specimens_df.pref_tf_dg)==False]
PMCux2cell_specimens_df=PMCux2cell_specimens_df[np.isfinite(PMCux2cell_specimens_df['pref_tf_dg'])]

PMRbp4cell_specimens_df=PMRbp4cell_specimens_df[np.isfinite(PMRbp4cell_specimens_df['pref_sf_sg'])]
PMRorbcell_specimens_df=PMRorbcell_specimens_df[np.isfinite(PMRorbcell_specimens_df['pref_sf_sg'])]
#PMScnn1cell_specimens_df=PMScnn1cell_specimens_df[np.isnan(PMScnn1cell_specimens_df.pref_sf_sg)==False]
PMCux2cell_specimens_df=PMCux2cell_specimens_df[np.isfinite(PMCux2cell_specimens_df['pref_sf_sg'])]

# %%
ALRbp4data=boc.get_ophys_experiments(cre_lines=['Rbp4-Cre'],targeted_structures=['VISal'])
ALRorbdata=boc.get_ophys_experiments(cre_lines=['Rorb-IRES2-Cre'],targeted_structures=['VISal'])
#PMScnn1data=boc.get_ophys_experiments(cre_lines=['Scnn1a-Tg3-Cre'],targeted_structures=['VISpm'])
ALCux2data=boc.get_ophys_experiments(cre_lines=['Cux2-CreERT2'],targeted_structures=['VISal'])

ALRbp4expt_list=pd.DataFrame(ALRbp4data).experiment_container_id.unique()
ALRorbexpt_list=pd.DataFrame(ALRorbdata).experiment_container_id.unique()
#PMScnn1expt_list=pd.DataFrame(PMScnn1data).experiment_container_id.unique()
ALCux2expt_list=pd.DataFrame(ALCux2data).experiment_container_id.unique()
# expt_container_id = expt_list[:]
#boc.get_experiment_containers(ids=[expt_list[0]])
ALRbp4cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=ALRbp4expt_list))
ALRorbcell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=ALRorbexpt_list))
#PMScnn1cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=PMScnn1expt_list))
ALCux2cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=ALCux2expt_list))

ALRbp4cell_specimens_df=ALRbp4cell_specimens_df[np.isfinite(ALRbp4cell_specimens_df['pref_tf_dg'])]
ALRorbcell_specimens_df=ALRorbcell_specimens_df[np.isfinite(ALRorbcell_specimens_df['pref_tf_dg'])]
#PMScnn1cell_specimens_df=PMScnn1cell_specimens_df[np.isnan(PMScnn1cell_specimens_df.pref_tf_dg)==False]
ALCux2cell_specimens_df=ALCux2cell_specimens_df[np.isfinite(ALCux2cell_specimens_df['pref_tf_dg'])]

ALRbp4cell_specimens_df=ALRbp4cell_specimens_df[np.isfinite(ALRbp4cell_specimens_df['pref_sf_sg'])]
ALRorbcell_specimens_df=ALRorbcell_specimens_df[np.isfinite(ALRorbcell_specimens_df['pref_sf_sg'])]
#PMScnn1cell_specimens_df=PMScnn1cell_specimens_df[np.isnan(PMScnn1cell_specimens_df.pref_sf_sg)==False]
ALCux2cell_specimens_df=ALCux2cell_specimens_df[np.isfinite(ALCux2cell_specimens_df['pref_sf_sg'])]

# %%
V1Rbp4data=boc.get_ophys_experiments(cre_lines=['Rbp4-Cre'],targeted_structures=['VISp'])
V1Rorbdata=boc.get_ophys_experiments(cre_lines=['Rorb-IRES2-Cre'],targeted_structures=['VISp'])
V1Scnn1data=boc.get_ophys_experiments(cre_lines=['Scnn1a-Tg3-Cre'],targeted_structures=['VISp'])
V1Cux2data=boc.get_ophys_experiments(cre_lines=['Cux2-CreERT2'],targeted_structures=['VISp'])

V1Rbp4expt_list=pd.DataFrame(V1Rbp4data).experiment_container_id.unique()
V1Rorbexpt_list=pd.DataFrame(V1Rorbdata).experiment_container_id.unique()
V1Scnn1expt_list=pd.DataFrame(V1Scnn1data).experiment_container_id.unique()
V1Cux2expt_list=pd.DataFrame(V1Cux2data).experiment_container_id.unique()
# expt_container_id = expt_list[:]
#boc.get_experiment_containers(ids=[expt_list[0]])
V1Rbp4cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=V1Rbp4expt_list))
V1Rorbcell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=V1Rorbexpt_list))
V1Scnn1cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=V1Scnn1expt_list))
V1Cux2cell_specimens_df = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=V1Cux2expt_list))

V1Rbp4cell_specimens_df=V1Rbp4cell_specimens_df[np.isfinite(V1Rbp4cell_specimens_df['pref_tf_dg'])]
V1Rorbcell_specimens_df=V1Rorbcell_specimens_df[np.isfinite(V1Rorbcell_specimens_df['pref_tf_dg'])]
V1Scnn1cell_specimens_df=V1Scnn1cell_specimens_df[np.isnan(V1Scnn1cell_specimens_df.pref_tf_dg)==False]
V1Cux2cell_specimens_df=V1Cux2cell_specimens_df[np.isfinite(V1Cux2cell_specimens_df['pref_tf_dg'])]

V1Rbp4cell_specimens_df=V1Rbp4cell_specimens_df[np.isfinite(V1Rbp4cell_specimens_df['pref_sf_sg'])]
V1Rorbcell_specimens_df=V1Rorbcell_specimens_df[np.isfinite(V1Rorbcell_specimens_df['pref_sf_sg'])]
V1Scnn1cell_specimens_df=V1Scnn1cell_specimens_df[np.isnan(V1Scnn1cell_specimens_df.pref_sf_sg)==False]
V1Cux2cell_specimens_df=V1Cux2cell_specimens_df[np.isfinite(V1Cux2cell_specimens_df['pref_sf_sg'])]

# %%
import math
from matplotlib import pyplot
import matplotlib.pyplot as plt

# %%
len(V1cell_specimens_df)
# Out:
# 3483

# %%
hg = np.histogram(V1cell_specimens_df.pref_sf_sg, bins=5)
hg2 = np.histogram(Valcell_specimens_df.pref_sf_sg, bins=5)
hg3 = np.histogram(Vlmcell_specimens_df.pref_sf_sg, bins=5)
hg4 = np.histogram(Vpmcell_specimens_df.pref_sf_sg, bins=5)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(V1cell_specimens_df)),'-o', label = 'V1')
ax.plot(hg2[1][:-1],hg2[0]/float(len(Valcell_specimens_df)),'-o',label = 'Val')
ax.plot(hg3[1][:-1],hg3[0]/float(len(Vlmcell_specimens_df)),'-o',label = 'V1m')
ax.plot(hg4[1][:-1],hg4[0]/float(len(Vpmcell_specimens_df)),'-o',label = 'Vpm')
tmp = type(hg[0])
plt.legend(loc='upper right')
plt.savefig('area_sfs.png')

# %%
hg = np.histogram(V1cell_specimens_df.pref_tf_dg, bins=5)
hg2 = np.histogram(Valcell_specimens_df.pref_tf_dg, bins=5)
hg3 = np.histogram(Vlmcell_specimens_df.pref_tf_dg, bins=5)
hg4 = np.histogram(Vpmcell_specimens_df.pref_tf_dg, bins=5)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(V1cell_specimens_df)),'-o', label = 'V1')
ax.plot(hg2[1][:-1],hg2[0]/float(len(Valcell_specimens_df)),'-o', label = 'Val')
ax.plot(hg3[1][:-1],hg3[0]/float(len(Vlmcell_specimens_df)),'-o', label = 'Vlm')
ax.plot(hg4[1][:-1],hg4[0]/float(len(Vpmcell_specimens_df)),'-o', label = 'Vpm')
tmp = type(hg[0])
plt.legend(loc='upper right')
plt.savefig('area_tfs.png')

# %%
hg = np.histogram(V1cell_specimens_df.pref_ori_sg, bins=6)
hg2 = np.histogram(Valcell_specimens_df.pref_ori_sg, bins=6)
hg3 = np.histogram(Vlmcell_specimens_df.pref_ori_sg, bins=6)
hg4 = np.histogram(Vpmcell_specimens_df.pref_ori_sg, bins=6)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(V1cell_specimens_df)),'-o', label = 'V1')
ax.plot(hg2[1][:-1],hg2[0]/float(len(Valcell_specimens_df)),'-o', label = 'Val')
ax.plot(hg3[1][:-1],hg3[0]/float(len(Vlmcell_specimens_df)),'-o', label = 'Vlm')
ax.plot(hg4[1][:-1],hg4[0]/float(len(Vpmcell_specimens_df)),'-o', label = 'Vpm')
tmp = type(hg[0])
plt.legend(loc='upper right')

# %%
hg = np.histogram(V1cell_specimens_df.pref_dir_dg, bins=8)
hg2 = np.histogram(Valcell_specimens_df.pref_dir_dg, bins=8)
hg3 = np.histogram(Vlmcell_specimens_df.pref_dir_dg, bins=8)
hg4 = np.histogram(Vpmcell_specimens_df.pref_dir_dg, bins=8)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(V1cell_specimens_df)),'-o', label = 'V1')
ax.plot(hg2[1][:-1],hg2[0]/float(len(Valcell_specimens_df)),'-o', label = 'Val')
ax.plot(hg3[1][:-1],hg3[0]/float(len(Vlmcell_specimens_df)),'-o', label = 'Vlm')
ax.plot(hg4[1][:-1],hg4[0]/float(len(Vpmcell_specimens_df)),'-o', label = 'Vpm')
tmp = type(hg[0])
plt.legend(loc='upper right')

# %%
hg = np.histogram(Rbp4cell_specimens_df.pref_dir_dg, bins=8)
hg2 = np.histogram(Rorbcell_specimens_df.pref_dir_dg, bins=8)
hg3 = np.histogram(Scnn1cell_specimens_df.pref_dir_dg, bins=8)
hg4 = np.histogram(Cux2cell_specimens_df.pref_dir_dg, bins=8)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(Rbp4cell_specimens_df)),'-o', label = 'Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(Rorbcell_specimens_df)),'-o', label = 'Rorb')
ax.plot(hg3[1][:-1],hg3[0]/float(len(Scnn1cell_specimens_df)),'-o', label = 'Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(Cux2cell_specimens_df)),'-o', label = 'Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')

# %%
hg = np.histogram(Rbp4cell_specimens_df.pref_ori_sg, bins=6)
hg2 = np.histogram(Rorbcell_specimens_df.pref_ori_sg, bins=6)
hg3 = np.histogram(Scnn1cell_specimens_df.pref_ori_sg, bins=6)
hg4 = np.histogram(Cux2cell_specimens_df.pref_ori_sg, bins=6)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(Rbp4cell_specimens_df)),'-o', label = 'Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(Rorbcell_specimens_df)),'-o', label = 'Rorb')
ax.plot(hg3[1][:-1],hg3[0]/float(len(Scnn1cell_specimens_df)),'-o', label = 'Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(Cux2cell_specimens_df)),'-o', label = 'Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')

# %%
hg = np.histogram(Rbp4cell_specimens_df.pref_sf_sg, bins=5)
hg2 = np.histogram(Rorbcell_specimens_df.pref_sf_sg, bins=5)
hg3 = np.histogram(Scnn1cell_specimens_df.pref_sf_sg, bins=5)
hg4 = np.histogram(Cux2cell_specimens_df.pref_sf_sg, bins=5)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(Rbp4cell_specimens_df)),'-o', label = 'Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(Rorbcell_specimens_df)),'-o', label = 'Rorb')
ax.plot(hg3[1][:-1],hg3[0]/float(len(Scnn1cell_specimens_df)),'-o', label = 'Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(Cux2cell_specimens_df)),'-o', label = 'Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')

# %%
hg = np.histogram(Rbp4cell_specimens_df.pref_tf_dg, bins=5)
hg2 = np.histogram(Rorbcell_specimens_df.pref_tf_dg, bins=5)
hg3 = np.histogram(Scnn1cell_specimens_df.pref_tf_dg, bins=5)
hg4 = np.histogram(Cux2cell_specimens_df.pref_tf_dg, bins=5)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(Rbp4cell_specimens_df)),'-o', label = 'Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(Rorbcell_specimens_df)),'-o', label = 'Rorb')
ax.plot(hg3[1][:-1],hg3[0]/float(len(Scnn1cell_specimens_df)),'-o', label = 'Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(Cux2cell_specimens_df)),'-o', label = 'Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')

# %%
hg = np.histogram(PMRbp4cell_specimens_df.pref_dir_dg, bins=8)
hg2 = np.histogram(PMRorbcell_specimens_df.pref_dir_dg, bins=8)
#hg3 = np.histogram(Scnn1cell_specimens_df.pref_dir_dg, bins=8)
hg4 = np.histogram(PMCux2cell_specimens_df.pref_dir_dg, bins=8)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(PMRbp4cell_specimens_df)),'-o', label = 'PM-Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(PMRorbcell_specimens_df)),'-o', label = 'PM-Rorb')
#ax.plot(hg3[1][:-1],hg3[0]/float(len(Scnn1cell_specimens_df)),'-o', label = 'Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(PMCux2cell_specimens_df)),'-o', label = 'PM-Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')

# %%
hg = np.histogram(PMRbp4cell_specimens_df.pref_ori_sg, bins=6)
hg2 = np.histogram(PMRorbcell_specimens_df.pref_ori_sg, bins=6)
#hg3 = np.histogram(Scnn1cell_specimens_df.pref_ori_sg, bins=6)
hg4 = np.histogram(PMCux2cell_specimens_df.pref_ori_sg, bins=6)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(PMRbp4cell_specimens_df)),'-o', label = 'PM-Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(PMRorbcell_specimens_df)),'-o', label = 'PM-Rorb')
#ax.plot(hg3[1][:-1],hg3[0]/float(len(Scnn1cell_specimens_df)),'-o', label = 'Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(PMCux2cell_specimens_df)),'-o', label = 'PM-Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')

# %%
hg = np.histogram(PMRbp4cell_specimens_df.pref_sf_sg, bins=5)
hg2 = np.histogram(PMRorbcell_specimens_df.pref_sf_sg, bins=5)
#hg3 = np.histogram(Scnn1cell_specimens_df.pref_sf_sg, bins=5)
hg4 = np.histogram(PMCux2cell_specimens_df.pref_sf_sg, bins=5)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(PMRbp4cell_specimens_df)),'-o', label = 'PM-Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(PMRorbcell_specimens_df)),'-o', label = 'PM-Rorb')
#ax.plot(hg3[1][:-1],hg3[0]/float(len(Scnn1cell_specimens_df)),'-o', label = 'Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(PMCux2cell_specimens_df)),'-o', label = 'PM-Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')
plt.savefig('PM_sfs.png')

# %%
hg = np.histogram(PMRbp4cell_specimens_df.pref_tf_dg, bins=5)
hg2 = np.histogram(PMRorbcell_specimens_df.pref_tf_dg, bins=5)
#hg3 = np.histogram(PMScnn1cell_specimens_df.pref_tf_dg, bins=5)
hg4 = np.histogram(PMCux2cell_specimens_df.pref_tf_dg, bins=5)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(PMRbp4cell_specimens_df)),'-o', label = 'PM-Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(PMRorbcell_specimens_df)),'-o', label = 'PM-Rorb')
#ax.plot(hg3[1][:-1],hg3[0]/float(len(PMScnn1cell_specimens_df)),'-o', label = 'PM-Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(PMCux2cell_specimens_df)),'-o', label = 'PM-Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')
plt.savefig('PM_tfs.png')

# %%
hg = np.histogram(V1Rbp4cell_specimens_df.pref_dir_dg, bins=8)
hg2 = np.histogram(V1Rorbcell_specimens_df.pref_dir_dg, bins=8)
hg3 = np.histogram(V1Scnn1cell_specimens_df.pref_dir_dg, bins=8)
hg4 = np.histogram(V1Cux2cell_specimens_df.pref_dir_dg, bins=8)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(V1Rbp4cell_specimens_df)),'-o', label = 'V1-Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(V1Rorbcell_specimens_df)),'-o', label = 'V1-Rorb')
ax.plot(hg3[1][:-1],hg3[0]/float(len(V1Scnn1cell_specimens_df)),'-o', label = 'V1-Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(V1Cux2cell_specimens_df)),'-o', label = 'V1-Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')

# %%
hg = np.histogram(V1Rbp4cell_specimens_df.pref_ori_sg, bins=6)
hg2 = np.histogram(V1Rorbcell_specimens_df.pref_ori_sg, bins=6)
hg3 = np.histogram(V1Scnn1cell_specimens_df.pref_ori_sg, bins=6)
hg4 = np.histogram(V1Cux2cell_specimens_df.pref_ori_sg, bins=6)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(V1Rbp4cell_specimens_df)),'-o', label = 'V1-Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(V1Rorbcell_specimens_df)),'-o', label = 'V1-Rorb')
ax.plot(hg3[1][:-1],hg3[0]/float(len(V1Scnn1cell_specimens_df)),'-o', label = 'V1-Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(V1Cux2cell_specimens_df)),'-o', label = 'V1-Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')

# %%
hg = np.histogram(V1Rbp4cell_specimens_df.pref_sf_sg, bins=5)
hg2 = np.histogram(V1Rorbcell_specimens_df.pref_sf_sg, bins=5)
hg3 = np.histogram(V1Scnn1cell_specimens_df.pref_sf_sg, bins=5)
hg4 = np.histogram(V1Cux2cell_specimens_df.pref_sf_sg, bins=5)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(V1Rbp4cell_specimens_df)),'-o', label = 'V1-Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(V1Rorbcell_specimens_df)),'-o', label = 'V1-Rorb')
ax.plot(hg3[1][:-1],hg3[0]/float(len(V1Scnn1cell_specimens_df)),'-o', label = 'V1-Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(V1Cux2cell_specimens_df)),'-o', label = 'V1-Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')

# %%
hg = np.histogram(V1Rbp4cell_specimens_df.pref_tf_dg, bins=5)
hg2 = np.histogram(V1Rorbcell_specimens_df.pref_tf_dg, bins=5)
hg3 = np.histogram(V1Scnn1cell_specimens_df.pref_tf_dg, bins=5)
hg4 = np.histogram(V1Cux2cell_specimens_df.pref_tf_dg, bins=5)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(V1Rbp4cell_specimens_df)),'-o', label = 'V1-Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(V1Rorbcell_specimens_df)),'-o', label = 'V1-Rorb')
ax.plot(hg3[1][:-1],hg3[0]/float(len(V1Scnn1cell_specimens_df)),'-o', label = 'V1-Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(V1Cux2cell_specimens_df)),'-o', label = 'V1-Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')

# %%
# hg = np.histogram(PMRbp4cell_specimens_df.pref_dir_dg, bins=8)
# hg2 = np.histogram(PMRorbcell_specimens_df.pref_dir_dg, bins=8)
# #hg3 = np.histogram(Scnn1cell_specimens_df.pref_dir_dg, bins=8)
# hg4 = np.histogram(PMCux2cell_specimens_df.pref_dir_dg, bins=8)
# plt.figure()
# fix,ax = plt.subplots(1)
# ax.plot(hg[1][:-1],hg[0]/float(len(PMRbp4cell_specimens_df)),'-o', label = 'PM-Rbp4')
# ax.plot(hg2[1][:-1],hg2[0]/float(len(PMRorbcell_specimens_df)),'-o', label = 'PM-Rorb')
# #ax.plot(hg3[1][:-1],hg3[0]/float(len(Scnn1cell_specimens_df)),'-o', label = 'Scnn1')
# ax.plot(hg4[1][:-1],hg4[0]/float(len(PMCux2cell_specimens_df)),'-o', label = 'PM-Cux2')
# tmp = type(hg[0])
# plt.legend(loc='upper right')

# %%
# hg = np.histogram(PMRbp4cell_specimens_df.pref_ori_sg, bins=6)
# hg2 = np.histogram(PMRorbcell_specimens_df.pref_ori_sg, bins=6)
# #hg3 = np.histogram(Scnn1cell_specimens_df.pref_ori_sg, bins=6)
# hg4 = np.histogram(PMCux2cell_specimens_df.pref_ori_sg, bins=6)
# plt.figure()
# fix,ax = plt.subplots(1)
# ax.plot(hg[1][:-1],hg[0]/float(len(PMRbp4cell_specimens_df)),'-o', label = 'PM-Rbp4')
# ax.plot(hg2[1][:-1],hg2[0]/float(len(PMRorbcell_specimens_df)),'-o', label = 'PM-Rorb')
# #ax.plot(hg3[1][:-1],hg3[0]/float(len(Scnn1cell_specimens_df)),'-o', label = 'Scnn1')
# ax.plot(hg4[1][:-1],hg4[0]/float(len(PMCux2cell_specimens_df)),'-o', label = 'PM-Cux2')
# tmp = type(hg[0])
# plt.legend(loc='upper right')

# %%
hg = np.histogram(ALRbp4cell_specimens_df.pref_sf_sg, bins=5)
hg2 = np.histogram(ALRorbcell_specimens_df.pref_sf_sg, bins=5)
#hg3 = np.histogram(Scnn1cell_specimens_df.pref_sf_sg, bins=5)
hg4 = np.histogram(ALCux2cell_specimens_df.pref_sf_sg, bins=5)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(ALRbp4cell_specimens_df)),'-o', label = 'AL-Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(ALRorbcell_specimens_df)),'-o', label = 'AL-Rorb')
#ax.plot(hg3[1][:-1],hg3[0]/float(len(Scnn1cell_specimens_df)),'-o', label = 'Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(ALCux2cell_specimens_df)),'-o', label = 'AL-Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')
plt.savefig('AL_sfs.png')

# %%
hg = np.histogram(ALRbp4cell_specimens_df.pref_tf_dg, bins=5)
hg2 = np.histogram(ALRorbcell_specimens_df.pref_tf_dg, bins=5)
#hg3 = np.histogram(PMScnn1cell_specimens_df.pref_tf_dg, bins=5)
hg4 = np.histogram(ALCux2cell_specimens_df.pref_tf_dg, bins=5)
plt.figure()
fix,ax = plt.subplots(1)
ax.plot(hg[1][:-1],hg[0]/float(len(ALRbp4cell_specimens_df)),'-o', label = 'AL-Rbp4')
ax.plot(hg2[1][:-1],hg2[0]/float(len(ALRorbcell_specimens_df)),'-o', label = 'AL-Rorb')
#ax.plot(hg3[1][:-1],hg3[0]/float(len(PMScnn1cell_specimens_df)),'-o', label = 'PM-Scnn1')
ax.plot(hg4[1][:-1],hg4[0]/float(len(ALCux2cell_specimens_df)),'-o', label = 'AL-Cux2')
tmp = type(hg[0])
plt.legend(loc='upper right')
plt.savefig('AL_tfs.png')
