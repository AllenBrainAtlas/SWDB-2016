# %% [markdown]
# # Scipy
# #### https://www.scipy.org/
#
# <br></br>
# ## core packages:
# 1. numpy
# 2. scipy library
# 3. matplotlib (will be covered)
# 4. IPython (will be covered mostly Jupyter notebook)
# 5. Sympy
# 6. pandas (will be covered)
#
# <br></br>
# ## scipy library:
# #### http://docs.scipy.org/doc/scipy/reference/

# %% [markdown]
# ## scipy library root includes some basic function (with a lot of overlapping with numpy)

# %%
import scipy
print dir(scipy)
# Out:
# ['ALLOW_THREADS', 'BUFSIZE', 'CLIP', 'ComplexWarning', 'DataSource', 'ERR_CALL', 'ERR_DEFAULT', 'ERR_IGNORE', 'ERR_LOG', 'ERR_PRINT', 'ERR_RAISE', 'ERR_WARN', 'FLOATING_POINT_SUPPORT', 'FPE_DIVIDEBYZERO', 'FPE_INVALID', 'FPE_OVERFLOW', 'FPE_UNDERFLOW', 'False_', 'Inf', 'Infinity', 'MAXDIMS', 'MachAr', 'ModuleDeprecationWarning', 'NAN', 'NINF', 'NZERO', 'NaN', 'PINF', 'PZERO', 'PackageLoader', 'RAISE', 'RankWarning', 'SHIFT_DIVIDEBYZERO', 'SHIFT_INVALID', 'SHIFT_OVERFLOW', 'SHIFT_UNDERFLOW', 'ScalarType', 'Tester', 'True_', 'UFUNC_BUFSIZE_DEFAULT', 'UFUNC_PYVALS_NAME', 'VisibleDeprecationWarning', 'WRAP', '__SCIPY_SETUP__', '__all__', '__builtins__', '__config__', '__doc__', '__file__', '__name__', '__numpy_version__', '__package__', '__path__', '__version__', '_lib', 'absolute', 'absolute_import', 'add', 'add_docstring', 'add_newdoc', 'add_newdoc_ufunc', 'add_newdocs', 'alen', 'all', 'allclose', 'alltrue', 'alterdot', 'amax', 'amin', 'angle', 'any', 'append', 'apply_along_axis', 'app
# ...

# %%
scipy.mean([1., 2., 3., 4.])
# Out:
# 2.5

# %% [markdown]
# ## scipy library also has somewhat 20 subpackages
# #### each subpackage contains a lot of useful functions
#
# 1. Clustering package (scipy.cluster)
# 2. Constants (scipy.constants)
# 3. Discrete Fourier transforms (scipy.fftpack)
# 4. Integration and ODEs (scipy.integrate)
# 5. Interpolation (scipy.interpolate)
# 6. Input and output (scipy.io)
# 7. Linear algebra (scipy.linalg)
# 8. Miscellaneous routines (scipy.misc)
# 9. Multi-dimensional image processing (scipy.ndimage)
# 10. Orthogonal distance regression (scipy.odr)
# 11. Optimization and root finding (scipy.optimize)
# 12. Signal processing (scipy.signal)
# 13. Sparse matrices (scipy.sparse)
# 14. Sparse linear algebra (scipy.sparse.linalg)
# 15. Compressed Sparse Graph Routines (scipy.sparse.csgraph)
# 16. Spatial algorithms and data structures (scipy.spatial)
# 17. Special functions (scipy.special)
# 18. Statistical functions (scipy.stats)
# 19. Statistical functions for masked arrays (scipy.stats.mstats)
# 20. C/C++ integration (scipy.weave)

# %% [markdown]
# ## To use the functions, the subpackage needs to be imported separately

# %%
import scipy.misc as misc

import matplotlib.pyplot as plt
# %matplotlib inline


plt.imshow(misc.face())
plt.show()

# %% [markdown]
# # Stack Overflow is your friend
# http://stackoverflow.com/
#
# ## powerful combination: google + stack overflow
